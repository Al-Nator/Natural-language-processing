# %% [markdown]
# Лабораторная работа №12: Изменение формы выражения текста без потери смысла
#
# Цель: Изменять структуру предложений и лексический состав текста, сохраняя его первоначальное значение.
# Задания:
# - Реализуйте методы перестановки порядка слов, замены синонимами и сокращения избыточных выражений, проверяя сохранение общего смысла.Метрика оценки: Человеческая экспертиза (оценка читабельности и сохранения смысла), сравнение показателей COMET или CHRF++.

# %% [markdown]
# # Обучение

# %%
import os
os.environ['UNSLOTH_COMPILE_DISABLE'] = '1'

from unsloth import FastModel
from unsloth.chat_templates import get_chat_template
from unsloth.chat_templates import standardize_data_formats
from unsloth.chat_templates import train_on_responses_only

import torch
from datasets import Dataset, DatasetDict, load_dataset, concatenate_datasets
import evaluate
import numpy as np
from trl import SFTTrainer, SFTConfig
from transformers import EarlyStoppingCallback
import pandas as pd
from tqdm.auto import tqdm
from evaluate import load
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
model, tokenizer = FastModel.from_pretrained(
    model_name = 'unsloth/gemma-3-4b-it',
    max_seq_length = 256, 
    load_in_4bit = False,  
    load_in_8bit = True,
    full_finetuning = False,
)

model = FastModel.get_peft_model(
    model,
    finetune_vision_layers = False, 
    finetune_language_layers = True,  
    finetune_attention_modules = True,  
    finetune_mlp_modules = True,  
    r = 16,           
    lora_alpha = 32,  
    lora_dropout = 0,
    bias = 'none',
    random_state = 3407,
)
# Out:
# ==((====))==  Unsloth 2025.4.7: Fast Gemma3 patching. Transformers: 4.51.3.
#    \\   /|    NVIDIA GeForce RTX 4070 Ti SUPER. Num GPUs = 1. Max memory: 15.593 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.9. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Unsloth: Making `model.base_model.model.language_model.model` require gradients

# %%
ds = load_dataset(
    'cointegrated/ru-paraphrase-NMT-Leipzig', 
    data_files={'train': 'train.csv', 'val': 'val.csv', 'test': 'test.csv'},
)

ds = DatasetDict({
    'train':      ds['train'],
    'validation': ds['val'],
    'test':       ds['test'],
})

def high_quality(example):
    return (example['labse_sim'] > 0.95) and (example['p_good'] > 0.95)

for split in ['train', 'validation', 'test']:
    ds[split] = ds[split].filter(high_quality, num_proc=4)

ds['validation'] = concatenate_datasets([ds['validation'], ds['test']])

ds = DatasetDict({
    'train':      ds['train'],
    'validation': ds['validation'],
})

def build_conversations(batch):
    return {
        'conversations': [
            [
              {'role': 'user',      'content': orig},
              {'role': 'assistant', 'content': ru}
            ]
            for orig, ru in zip(batch['original'], batch['ru'])
        ]
    }

ds = ds.map(
    build_conversations, batched=True,
    remove_columns=['idx','en',
                    'chrf_sim','labse_sim',
                    'forward_entailment','backward_entailment',
                    'p_good','original','ru']
)

ds = ds.map(lambda x: {'text': tokenizer.apply_chat_template(x['conversations'])},
            batched=True)

ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['conversations', 'text'],
#         num_rows: 108434
#     })
#     validation: Dataset({
#         features: ['conversations', 'text'],
#         num_rows: 2155
#     })
# })

# %%
def apply_template(batch):
    return {'text': tokenizer.apply_chat_template(batch['conversations'])}

ds = ds.map(apply_template, batched=True)

print(ds['train'][0]['text'])
# Out:
# Map:   0%|          | 0/108434 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2155 [00:00<?, ? examples/s]
# <bos><start_of_turn>user
# А вот количество ТОП-ов от одного пользователя не ограничено!<end_of_turn>
# <start_of_turn>model
# Но количество ТОПов на пользователя не ограничивается!<end_of_turn>

# %%
train_std = standardize_data_formats(ds['train'])
valid_std = standardize_data_formats(ds['validation'])

ds = DatasetDict({
    'train': train_std,
    'validation': valid_std,
})

ds
# Out:
# Unsloth: Standardizing formats (num_proc=12):   0%|          | 0/108434 [00:00<?, ? examples/s]
# Unsloth: Standardizing formats (num_proc=12):   0%|          | 0/2155 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['conversations', 'text'],
#         num_rows: 108434
#     })
#     validation: Dataset({
#         features: ['conversations', 'text'],
#         num_rows: 2155
#     })
# })

# %%
ds['train'][0]
# Out:
# {'conversations': [{'content': 'А вот количество ТОП-ов от одного пользователя не ограничено!',
#    'role': 'user'},
#   {'content': 'Но количество ТОПов на пользователя не ограничивается!',
#    'role': 'assistant'}],
#  'text': '<bos><start_of_turn>user\nА вот количество ТОП-ов от одного пользователя не ограничено!<end_of_turn>\n<start_of_turn>model\nНо количество ТОПов на пользователя не ограничивается!<end_of_turn>\n'}

# %%
def apply_chat_template(examples):
    texts = tokenizer.apply_chat_template(examples['conversations'])
    return {'text': texts }

dataset = ds.map(apply_chat_template, batched=True)
# Out:
# Map:   0%|          | 0/108434 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2155 [00:00<?, ? examples/s]

# %%
early_stop_cb = EarlyStoppingCallback(
    early_stopping_patience=3,          
)
    
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = ds['train'],
    eval_dataset = ds['validation'], 
    args = SFTConfig(
        output_dir = 'results/gemma_paraphrase',
        dataset_text_field = 'text',
        per_device_train_batch_size = 8,
        per_device_eval_batch_size=8,
        gradient_accumulation_steps=2,
        num_train_epochs = 5,
        warmup_steps = 5,
        eval_strategy='steps',
        learning_rate = 5e-5, 
        logging_steps = 300,
        eval_steps=300,
        optim = 'adamw_8bit',
        weight_decay = 0.01,
        lr_scheduler_type = 'linear',
        seed = 3407,
        report_to = 'none',
    ),
    callbacks = [early_stop_cb],
)

trainer.args.save_strategy = 'steps'
trainer.args.save_steps = trainer.args.eval_steps  
trainer.args.load_best_model_at_end = True                       
trainer.args.metric_for_best_model = 'eval_loss'             
trainer.args.greater_is_better = False
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=12):   0%|          | 0/108434 [00:00<?, ? examples/s]
# Unsloth: Tokenizing ["text"] (num_proc=12):   0%|          | 0/2155 [00:00<?, ? examples/s]

# %%
trainer = train_on_responses_only(
    trainer,
    instruction_part = '<start_of_turn>user\n',
    response_part = '<start_of_turn>model\n',
)
# Out:
# Map (num_proc=12):   0%|          | 0/108434 [00:00<?, ? examples/s]
# Map (num_proc=12):   0%|          | 0/2155 [00:00<?, ? examples/s]

# %%
tokenizer.decode(trainer.train_dataset[0]['input_ids'])
# Out:
# '<bos><bos><start_of_turn>user\nА вот количество ТОП-ов от одного пользователя не ограничено!<end_of_turn>\n<start_of_turn>model\nНо количество ТОПов на пользователя не ограничивается!<end_of_turn>\n'

# %%
tokenizer.decode([tokenizer.pad_token_id if x == -100 else x for x in trainer.train_dataset[0]['labels']]).replace(tokenizer.pad_token, ' ')
# Out:
# '                         Но количество ТОПов на пользователя не ограничивается!<end_of_turn>\n'

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 108,434 | Num Epochs = 5 | Total steps = 33,885
# O^O/ \_/ \    Batch size per device = 8 | Gradient accumulation steps = 2
# \        /    Data Parallel GPUs = 1 | Total batch size (8 x 2 x 1) = 16
#  "-____-"     Trainable parameters = 29,802,496/4,329,881,968 (0.69% trained)
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='7500' max='33885' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 7500/33885 2:05:18 < 7:20:58, 1.00 it/s, Epoch 1/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>300</td>
#       <td>0.822700</td>
#       <td>0.704674</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.691400</td>
#       <td>0.673307</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.675400</td>
#       <td>0.656409</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.659400</td>
#       <td>0.644682</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.644800</td>
#       <td>0.637910</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.631100</td>
#       <td>0.628795</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.628100</td>
#       <td>0.621444</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.612000</td>
#       <td>0.613707</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.612500</td>
#       <td>0.608900</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.610600</td>
#       <td>0.602451</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.600400</td>
#       <td>0.599787</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.602900</td>
#       <td>0.594341</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.598100</td>
#       <td>0.592264</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.599600</td>
#       <td>0.588100</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.593600</td>
#       <td>0.583221</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.588300</td>
#       <td>0.580251</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.586900</td>
#       <td>0.582031</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.581100</td>
#       <td>0.574740</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.578300</td>
#       <td>0.572824</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.577700</td>
#       <td>0.570320</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>0.567900</td>
#       <td>0.569344</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.575200</td>
#       <td>0.568741</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>0.534800</td>
#       <td>0.571460</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.466500</td>
#       <td>0.575922</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.464700</td>
#       <td>0.572676</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Not an error, but Gemma3ForConditionalGeneration does not accept `num_items_in_batch`.
# Using gradient accumulation will be very slightly less accurate.
# Read more on gradient accumulation issues here: https://unsloth.ai/blog/gradient

# %%
model.save_pretrained('results/gemma_paraphrase/best')  
tokenizer.save_pretrained('results/gemma_paraphrase/best')
# Out:
# ['results/gemma_paraphrase/best/processor_config.json']

# %% [markdown]
# # Оценка

# %%
tokenizer = get_chat_template(
    tokenizer,
    chat_template = 'gemma-3',
)
messages = [{
    'role': 'user',
    'content': [{
        'type' : 'text',
        'text' : 'США выиграли чемпионат мира по хоккею.'
    }]
}]
text = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True,
)
outputs = model.generate(
    **tokenizer([text], return_tensors = 'pt').to('cuda'),
    max_new_tokens = 64, 
    temperature = 1.0, top_p = 0.95, top_k = 64,
)
tokenizer.batch_decode(outputs)
# Out:
# ['<bos><start_of_turn>user\nСША выиграли чемпионат мира по хоккею.<end_of_turn>\n<start_of_turn>model\nСША стали чемпионами мира в хоккее.<end_of_turn>']

# %%
model, tokenizer = FastModel.from_pretrained(
    model_name     = 'results/gemma_paraphrase/best',
    max_seq_length = 256,
    load_in_4bit   = False,
    load_in_8bit   = True,
)
tokenizer = get_chat_template(tokenizer, chat_template='gemma-3')
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device).eval()

ds = load_dataset(
    'cointegrated/ru-paraphrase-NMT-Leipzig',
    data_files={'train': 'train.csv', 'val': 'val.csv', 'test': 'test.csv'},
)
ds = DatasetDict({
    'train':      ds['train'],
    'validation': ds['val'],
    'test':       ds['test'],
})

def high_quality(example):
    return (example['labse_sim'] > 0.95) and (example['p_good'] > 0.95)

for split in ['train', 'validation', 'test']:
    ds[split] = ds[split].filter(high_quality, num_proc=4)

ds['validation'] = concatenate_datasets([ds['validation'], ds['test']])
ds = DatasetDict({
    'train':      ds['train'],
    'validation': ds['validation'],
})

def build_conversations(batch):
    return {
        'conversations': [
            [
              {'role': 'user',      'content': orig},
              {'role': 'assistant', 'content': ru}
            ]
            for orig, ru in zip(batch['original'], batch['ru'])
        ]
    }

ds = ds.map(
    build_conversations, batched=True,
    remove_columns=[
        'idx','en',
        'chrf_sim','labse_sim',
        'forward_entailment','backward_entailment',
        'p_good','original','ru'
    ]
)

ds = ds.map(lambda x: {'text': tokenizer.apply_chat_template(x['conversations'])}, batched=True)
train_std = standardize_data_formats(ds['train'])
valid_std = standardize_data_formats(ds['validation'])
ds = DatasetDict({'train': train_std, 'validation': valid_std})

batch_size = 32
preds = []
sources = []
refs  = []

for i in tqdm(range(0, len(ds['validation']), batch_size), desc='Generating'):
    batch = ds['validation'][i : i + batch_size]
    sources.extend([ conv[0]['content'] for conv in batch['conversations'] ])
    refs.extend([ conv[1]['content'] for conv in batch['conversations'] ])

    raw = tokenizer.apply_chat_template(batch['conversations'], tokenize=False, add_generation_prompt=True)
    inputs = tokenizer(
        raw, return_tensors='pt', padding=True, truncation=True, padding_side='left'
    ).to(device)
    prompt_len = inputs.input_ids.shape[1]

    out = model.generate(
        input_ids      = inputs.input_ids,
        attention_mask = inputs.attention_mask,
        max_new_tokens = 128,
        temperature    = 1.0,
        top_p          = 0.95,
        top_k          = 64,
        pad_token_id   = tokenizer.pad_token_id,
        eos_token_id   = tokenizer.eos_token_id
    )
    gen = out[:, prompt_len:]
    txt = tokenizer.batch_decode(gen, skip_special_tokens=True)
    preds.extend([t.strip() for t in txt])

bertscore = evaluate.load('bertscore')
bs = bertscore.compute(
    predictions = preds,
    references  = [[r] for r in refs],
    lang        = 'ru',
    batch_size  = batch_size,
    device      = device
)

print(f'\nBERTScore F1 (vs референс):        {np.array(bs['f1']).mean():.4f}')
print(f'BERTScore Precision (vs референс): {np.array(bs['precision']).mean():.4f}')
print(f'BERTScore Recall (vs референс):    {np.array(bs['recall']).mean():.4f}')
# Out:
# /tmp/ipykernel_46506/2068443850.py:7: UserWarning: WARNING: Unsloth should be imported before transformers to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastModel
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.4.7: Fast Gemma3 patching. Transformers: 4.51.3.
#    \   /|    NVIDIA GeForce RTX 4070 Ti SUPER. Num GPUs = 1. Max memory: 15.593 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.9. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Generating: 100%|██████████| 68/68 [05:19<00:00,  4.70s/it]
#
# BERTScore F1 (vs референс):        0.8813
# BERTScore Precision (vs референс): 0.8831
# BERTScore Recall (vs референс):    0.8799

# %%
n = len(preds)
dummy_refs = [''] * n

comet = load(
    'comet',
    module_type='metric',
    checkpoint='Unbabel/wmt22-cometkiwi-da'
)

res = comet.compute(
    predictions=preds,
    sources=sources,
    references =refs,
)
print('COMET score:', res['mean_score'])
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Lightning automatically upgraded your loaded checkpoint from v1.8.3.post1 to v2.5.1.post0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../../.cache/huggingface/hub/models--Unbabel--wmt22-comet-da/snapshots/2760a223ac957f30acfb18c8aa649b01cf1d75f2/checkpoints/model.ckpt`
# Encoder model frozen.
# /home/danya/anaconda3/envs/new/lib/python3.12/site-packages/pytorch_lightning/core/saving.py:195: Found keys that are not in the model state dict but in the checkpoint: ['encoder.model.embeddings.position_ids']
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# COMET score: 0.9303978350627173

# %%
mapping = { s:(p,[r]) for s,p,r in zip(sources,preds,refs) }
seen = set()
for i, conv in enumerate(ds['validation']['conversations']):
    src = conv[0]['content']
    if src in seen:
        continue
    seen.add(src)
    pred, ref_list = mapping[src]
    print(f'\n[{i}] Оригинал:  {src}')
    print(f'    Референс: {ref_list[0]}')
    print(f'    Модель:    {pred}')
# Out:
# [0] Оригинал:  Это биотехнологи, не имеющие медицинского образования, просто купившие секвенатор и продающие некую технологическую услугу.
#     Референс: Речь идет о биотехнологах без медицинской подготовки, которые просто купили секвенсор и продали какой-то технологический сервис.
#     Модель:    Это биотехнологи, не имеющие медицинской степени, которые просто купили секвенирование и продали технологическую услугу.
#
# [1] Оригинал:  Ему казалось, что картины разбушевавшихся стихий: лавины, бури, метели и урагана - вообще, всякие чрезвычайные состояния природы могут адекватно передать смятение человеческого сердца и ума, очистить душу и сознание.
#     Референс: Ему показалось, что образы бушующей стихии: лавин, штормов, метелей и ураганов - в общем, всякого рода экстремальных состояний природы способны адекватно выразить бурю сердца и разума человека, очиститься душа и сознание.
#     Модель:    Ему представлялось, что картины бушующих стихий - лавины, бури, метели и ураганы - в целом всякие необычные природные явления могут в адекватной форме передать смятение человеческого разума и сердца, очистить и успокоить душу и разум.
#
# [2] Оригинал:  Отсутствие контроля разума со стороны человека делает возможным появление спонтанных или свободных (сознательных) действий, выпадающих из цепи ранее установленных фактов и правил.
#     Референс: Отсутствие у человека контроля над разумом позволяет совершать спонтанные или свободные (сознательные) действия, выпав из цепочки ранее установленных обстоятельств и правил.
#     Модель:    Когда человек не имеет над разумом контроля, возможны спонтанные или свободные (осознанные) поступки, которые выходят за рамки ранее установленных фактов и норм.
#
# [3] Оригинал:  Удаляет токсины тяжёлых металлов, остатки косметики, пыль, очищает кожу от угрей и сыпи, предотвращает образование дряблой кожи.
#     Референс: Избавляет от токсинов тяжелых металлов, косметических остатков, пыли, чистит кожу с угрем и сыпью, препятствует образованию дряблой кожи.
#     Модель:    Удаляет от токсинов тяжелых металлов, остатки косметики и пыли, очищает кожу от угревых прищней и сыпей, предотвращает образование растрескивающейся кожи.
#
# [4] Оригинал:  А как же коллективная ответственность?
#     Референс: А как насчет коллективной ответственности?
#     Модель:    А коллективную ответственность?
#
# [5] Оригинал:  Особенно это актуально для высокотехнологичной продукции с множеством параметров и характеристик.
#     Референс: Особенно это касается высокотехнологичных продуктов со многими параметрами и характеристиками.
#     Модель:    Это особенно актуально для высокотехнологичных продуктов, которые имеют много параметров и свойств.
#
# [6] Оригинал:  Задержитесь здесь на несколько секунд.
#     Референс: Держитесь здесь несколько секунд.
#     Модель:    Постойте здесь на пару секунд.
#
# [7] Оригинал:  Также обсуждался вопрос мотивации студентов и молодых специалистов для работы на крупных научных проектах.
#     Референс: Обсуждался также вопрос о мотивации учащихся и молодых профессионалов к работе над крупными научно-исследовательскими проектами.
#     Модель:    Кроме того, обсуждалась мотивация студентов и молодых специалистов на участие в крупных научных проектах.
#
# [8] Оригинал:  Самое важное, что все они характеризуются универсальностью, безопасностью, компактностью, надежностью и экологичностью.
#
# [20] Оригинал:  Это символизирует старость и смерть, то есть тот факт, что родившись, мы сразу же идем к смерти.
#     Референс: Это символ старости и смерти, т.е. того факта, что когда мы рождаемся, мы идем прямо к смерти.
#     Модель:    Это символизирует старение и смерть - то есть, что рожденные люди сразу же идут к смерти.
#
# [21] Оригинал:  Я работала няней в нескольких семьях, с детьми от 2 до 9 лет.
#     Референс: Я работал няней для нескольких семей с детьми в возрасте 2-9 лет.
#     Модель:    Я работал воспитателем для нескольких семей, детей от 2-х до 9-ти лет.
#
# [22] Оригинал:  Она была не одна, их было много…
#     Референс: Она не была одинока, таких было много...
#     Модель:    Она не оставалась одна, их было такое много...
#
# [23] Оригинал:  Многофунцианальная систем для брони позволяющая работать с любыми типами электронного и технического оборудования.
#     Референс: Многофункциональные системы брони, которые позволяют работать со всеми видами электронного и технологического оборудования.
#     Модель:    Многофункциональная система бронирования, которая позволяет работать с любой техникой и оборудованием.
#
# [24] Оригинал:  Максимальное превышение аукционной стоимости над стартовой достигало 400 процентов.
#     Референс: Максимальная цена аукциона превышала стартовую на 400 процентов.
#     Модель:    Максимальный перевес цены аукциона над стартом составил 400 процентов.
#
# [25] Оригинал:  Правда-ли, что Русский стандарт обманывает клиентов?
#     Референс: Это правда, что "Русский стандарт" вводит клиентов в заблуждение?
#     Модель:    Правдиво ли, что "Русский Стандарт" обманывает покупателей?
#
# [26] Оригинал:  Я не знал, что будет следующим и никто не знал.
#     Референс: Я не знала, что произойдет дальше, и никто об этом не знал.
#     Модель:    Я не знала, что последует дальше, и никто ее не знал.
#
# [27] Оригинал:  Дети, которые внимательно слушали, смогли грамотно ответить на поставленные вопросы и получить сладкие призы - конфеты.
#     Референс: Внимательно прислушавшиеся дети смогли грамотным образом ответить на заданные вопросы и получили сладкие подарки - сладости.
#     Модель:    Дети, которые внимательно слушали, смогли правильно ответить на вопросы и получить сладости - конфеты.
#
# [28] Оригинал:  Каковы были эти семь слов?
#     Референс: Что это были за семь слов?
#     Модель:    Какие эти семь слов?
#
# [29] Оригинал:  Оно было словно пустое.
#     Референс: Это было как будто пусто.
#     Модель:    Это было похоже на пустоту.
#
# [30] Оригинал:  Но он вернул шайбу мне, сделал свой подарок.
#     Референс: Но вернул мне шайбу, сделал подарок.
#     Модель:    Но он мне вернул шайбу, сделал свой подарок.
#
# [31] Оригинал:  Сегодня можно констатировать отсутствие стратегии системы нормотворчества в данной сфере государственного управления.
#     Референс: Сегодня можно сказать, что в этой области государственного управления нет стратегии для нормотворческой системы.
#     Модель:    Сегодня можно сказать, что стратегии для нормотворческого механизма в этой области государственного управления нет.
#
# [32] Оригинал:  Вот еще один пример такого же рода.
#     Референс: Вот ещё один пример того же рода.
#     Модель:    Вот еще пример того же типа.
#
# [33] Оригинал:  Ты когда-нибудь был(ла) в замке?
#     Референс: Бывали ли вы когда-либо в замок?
#     Модель:    Вы когда-нибудь посещали замок?
#
# [34] Оригинал:  Национальные выставочные экспозиции представили 8 иностранных государств (Армения, Белоруссия, Индия, Казахстан, Китай, Пакистан, Словакия, Турция).
#     Референс: Национальные выставки были представлены 8 зарубежными странами (Арменией, Беларусью, Индией, Казахстаном, Китаем, Пакистаном, Словакией, Турцией).
#     Модель:    Национальные выставочные выставки представлеными были 8 зарубежными государствами (Армения, Беларусь, Индия, Казахстан, Китай, Пакистан, Словения, Турция).
#
# [35] Оригинал:  Так вы будете точно знать что кофе свежий и качественный.
#     Референс: Таким образом, вы точно узнаете, какой кофе является свежим и качественным.
#     Модель:    Так что вы точно знаете, что кофе свежая и качественная.
#
# [36] Оригинал:  Но учтите: МНЕ ваша защита не нужна.
#     Референс: Но имейте в виду: мне не нужна ваша защита.
#     Модель:    Но обратите внимание: мне не нужна твоя защита.
#
# [37] Оригинал:  Ущемления чьих-то интересов мы не видим, все работают в одинаковых условиях.
#     Референс: Мы не видим ущемления чьи-либо интересов, каждый работает в одних и тех же условиях.
#     Модель:    Мы не видим пренебрежения к чьим-либо интересам, каждый работает под одинаковыми условиями.
#
# [38] Оригинал:  Ты начинаешь замечать воздух только тогда, когда он почти закончился.
#     Референс: Воздух вы начинаете замечать, только когда он уже почти закончился.
#     Модель:    Вы начинаете обращать внимание на воздух, когда он почти кончился.
#
# [39] Оригинал:  Устанавливаемые в пищеблоках двери относятся к категории технических, а, следовательно, особенных требований к их дизайну не предъявляется.
#     Референс: Двери, установленные в кухонных блоках, классифицируются как технические и поэтому не имеют каких-либо специальных требований к дизайну.
#     Модель:    Установленные в кухнях двери считаются техническими, поэтому и не имеют особых требований к дизайну.
#
# [40] Оригинал:  Для того, чтобы отличить одни от других, ученые обычно просят исследуемых вспомнить ситуацию в контексте, что осложняет задачу в случае с поддельными воспоминаниями.
#     Референс: Чтобы отличить одно от другого, учёные обычно просят испытуемых вспомнить контекст ситуации, что усложняет задачу при поддельных воспоминаниях.
#     Модель:    Чтобы отличить их друг от друга, ученые обычно просят тестируемых вспомнить ситуацию, в контексте чего все это осложняет задачу при поддельных воспоминаниях.
#
# [41] Оригинал:  В нем располагаются лаборатории геоинформатики, графического и промышленного дизайна, робототехники.
#     Референс: В нем расположены лаборатории по геоинформатике, графическому и промышленному дизайну, а также робототехнике.
#     Модель:    Он включает в себя лаборатории по геоинформатике, графическому и промышленному дизайну, робототехнике.
#
# [42] Оригинал:  Все это похоже на какой-то бред, а на фоне происходящего конца света и вовсе ненужной шуткой.
#     Референс: Все это выглядит как какая-то ерунда, и на фоне конца света вообще происходит ненужная шутка.
#     Модель:    Все это напоминает какую-то дичь, и на фоне конца света это вообще ненужное представление.
#
# [43] Оригинал:  Какие преимущества обеспечивает эксцентрик?
#     Референс: Какие преимущества дает эксцентрика?
#     Модель:    Какие преимущества предоставляет эксцентрики?
#
# [44] Оригинал:  Никто достоверно не знает, что произойдет в будущем.
#     Референс: Никто не знает точно, что случится в будущем.
#     Модель:    Никто не знает наверняка, что будет в будущем.
#
# [45] Оригинал:  Здесь возможно было бы прикольно обосновать появление у персонажа демонической стали, которую я выиграла в одной из игровых лотерей.
#     Модель:    Самым популярным и актуальным способом запуска устройства является запуск через мобильное устройство.
#
# [91] Оригинал:  К переработке сырья завод приступит в понедельник, 6 мая.
#     Референс: Завод начнет перерабатывать сырье в понедельник 6 мая.
#     Модель:    Переработка сырья на заводе начнется в понедельник 6 мая.
#
# [92] Оригинал:  Может быть, надо только одно –
#     Референс: Возможно, нужно только одно -
#     Модель:    Может, нужно просто одно -
#
# [93] Оригинал:  То, что на Земле называют плохим, создали частью люди, частью те, кто участвуют в исследовании.
#     Референс: Что называется плохим на Земле, было создано частично людьми, частично теми, кто участвовал в исследовании.
#     Модель:    То, что является плохим на земле, было создано людьми частично и исследователями частично.
#
# [94] Оригинал:  Это те самые ситуации, когда невозможно точно поставить диагноз, определить причину развития.
#     Референс: Это как раз те ситуации, в которых невозможно поставить точный диагноз и установить причину развития.
#     Модель:    Это ситуациях, когда невозможно точно установить диагноз и определить причины развития.
#
# [95] Оригинал:  Фестиваль начнет свою работу 28 сентября и продлится до 7 октября.
#     Референс: Фестиваль начнётся 28-го сентября и продолжится до 7-го октября.
#     Модель:    Фестиваль начнется 28 сентября, продлится до 7 октября.
#
# [96] Оригинал:  Но самое главное я почувствовала огонь.
#     Референс: Но главное, я почувствовал огонь.
#     Модель:    Но самое главное - я почувствовал огонь.
#
# [97] Оригинал:  О чем бы Вы подумали в этот момент?
#     Референс: Что бы вы думали в данный момент?
#     Модель:    Что вы бы подумали в тот момент?
#
# [98] Оригинал:  Сайт посвящен 250-ой стрелковой дивизии и её боевому пути.
#     Референс: Сайт посвящён 250-й стрелковой дивизие и её боевой путь.
#     Модель:    Сайт посвящён 250й стрелковой дивизии и её боевому маршу.
#
# [99] Оригинал:  Он скажет: «Мой дорогой сын, подойди сюда и тихо сядь.
#     Референс: Он будет говорить: "Дорогой сын, приходи сюда и сиди тихо.
#     Модель:    Он будет говорить "Дорогой мой сын, подойди сюда и сядь тихо.
#
# [100] Оригинал:  А если захочется там посидеть и два, и три часа в компьютере, нет?
#     Референс: А если вы хотите посидеть там два-три часа за компьютером, нет?
#     Модель:    А если вы хотите сидеть там два или три часа на компьютере, то нет?
#
# [101] Оригинал:  Ну и романтик же вы!
#     Референс: Ну, вы же романтик!
#     Модель:    Ну, ты романтик!
#
# [102] Оригинал:  Будьте самим собой."
#     Референс: Будь собой ".
#     Модель:    Будь собой ".
#
# [103] Оригинал:  Особенно это не понимал Китай, когда тут же предложил свою помощь.
#     Референс: Китай, в частности, не понял этого, когда сразу же предложил помощь.
#     Модель:    Особенно Китай не понял этого, сразу же предложив свою помощь.
#
# [104] Оригинал:  И здесь есть юноши, которые в своем невежестве желают низвести этот идеал вместо того, чтобы очистить его и восстановить древний индусский брак.
#     Референс: И здесь тоже есть молодые люди, которые по своему невежеству желают разрушить данный идеал, вместо того чтобы его очистить и восстановить старинный индуистский брак.
#     Модель:    А здесь есть парни, которые в невежестве хотят низложить этот идеал, а не очистить и восстановить древнюю индийскую семью.
#
# [105] Оригинал:  Много работы было у женщин.
#     Референс: У женщин было много работы.
#     Модель:    Женщины много работали.
#
# [106] Оригинал:  Значит, частота соответствует переходу электронов в атоме и равна эталонной.
#     Референс: Таким образом, частоты соответствуют переходу электринов в атом и равны эталонным.
#     Модель:    То есть частоты соответствуют переходу электронов от атома и равны эталонным.
#
# [107] Оригинал:  Анджелина Джоли и Брэд Питт официально развелись.
#     Референс: Анджелину Джоли с Брэдом Питтом официально развели.
#     Модель:    Анджелина Джоли и Брэд Питт официально разводятся.
#
# [108] Оригинал:  Может, война после такого наконец закончится.
#     Референс: Может быть, после этого война наконец-то закончится.
#     Модель:    Возможно, после этого война, наконец, закончится.
#
# [109] Оригинал:  Кроме этого, глазам нужно правильное питание.
#     Референс: Кроме того, глаза нуждаются в правильном питании.
#     Модель:    Кроме того, глазам необходима правильная пища.
#
# [110] Оригинал:  Его тёплые добрые руки, его мягкие волосы, его пронзительной глубины тёмные глаза, а этот запах весенне-осеннего леса!
#     Референс: Его теплые хорошие руки, нежные волосы, щемящая глубина темных глаз и тот запах леса весны-осени!
#     Модель:    Его теплые добродушные руки, его мягкий волос, его проникающая глубина темных глаз и этот весенний-осенний дух леса!
#
# [111] Оригинал:  Знаете, на самом деле, это даже звучит сомнительно.
#     Референс: Вы знаете, в действительности это звучит даже сомнительно.
#     Модель:    На самом деле это даже звучит подозрительно.
#
# [112] Оригинал:  С 2001 года компания создала более 1 000 сайтов для 500 клиентов.
#     Референс: Начиная с 2001 года, компанией создано более 1000 сайтов на 500 клиентов.
#     Модель:    Компания с 2001 года создала свыше 1000 веб-сайтов для своих 500 клиентов.
#
# [113] Оригинал:  Думаю, данная договоренность принесет синергетический эффект.
#     Референс: Я думаю, что это соглашение будет иметь синергический эффект.
#     Модель:    Я думаю, что это соглашение будет приносить синергию.
#
# [114] Оригинал:  Исследователи выявили пока лишь 1,4 млн видов животных; ещё несколько миллионов ждут, когда их обнаружат, назовут и опишут.
#     Референс: Исследователи идентифицировали пока только 1,4 миллиона видов животных, еще несколько миллионов ожидают открытия, названия и описания.
#     Модель:    На сегодняшний день исследователи выявили лишь 1,4 миллиона видов животных, несколько миллионов из которых еще не обнаружены, названы или описаны.
#
# [115] Оригинал:  У вас, я так понимаю, проблема в невозможности нажать кнопку администрирования?
#     Референс: Есть ли у вас, как я понимаю, проблемы с невозможностью нажать административную кнопку?
#     Модель:    Судя по всему, у вас проблема с нажатием административной кнопки?
#
# [116] Оригинал:  Желание все изменить.
#     Референс: Желание изменить все.
#     Модель:    Желание изменить все.
#
# [117] Оригинал:  Да, имеет смысл.
#     Референс: Да, это имеет смысл.
#     Модель:    Да, это вполне логично.
#
# [118] Оригинал:  За 6 лет (с осени 2002 года) общее число пользователей выросло в 4,4 раза.
#     Референс: За шесть лет (начиная с осени 2002г.) общее количество пользователей увеличилось в 4.4 раза.
#     Модель:    За шесть лет - с осени 2002г. - общее число пользователей росло в 4,4 раза.
#
# [119] Оригинал:  В сентябре и октябре здесь по-прежнему тепло (+18–22 °C), да и ноябрь с его средней температурой +12–15 °C также не очень холодный месяц.
# [2118] Оригинал:  Это все стоит немалых денег, и не всегда хочется их отдавать.
#     Референс: Все это стоит больших денег, а отдавать их хочется не всегда.
#     Модель:    Это все очень дорого, и не всегда хочется отдавать.
#
# [2119] Оригинал:  Я такой же пользователь как и вы, я имею права высказать свое мнение, я его высказываю.
#     Референс: Я тот же пользователь, что и ты, у меня есть право высказывать, я выражаю свое мнение.
#     Модель:    Я также пользователь, у меня есть право выражать своё мнение, и я его выражаю.
#
# [2120] Оригинал:  Но несмотря на распространенность интернет-технологий, не все россияне доверяют виртуальной покупке билетов.
#     Референс: Но, несмотря на всепроникающее проникновение интернет-технологии, не всем россиянам доверяют покупки виртуальных билетов.
#     Модель:    Однако, несмотря на распространение Интернет-технологий, далеко не все граждане России доверяют виртуальной покупке билетов.
#
# [2121] Оригинал:  В связи с последними открытиями, информация слегка обновлена.
#     Референс: С учетом последних открытий, информация немного обновляется.
#     Модель:    Учитывая последние открытия, информация обновлена в небольшой степени.
#
# [2122] Оригинал:  Консалтинговые услуги имеют длительный цикл продажи.
#     Референс: У консалтинговых услуг длинный цикл продаж.
#     Модель:    Консалтинговые услуги обладают длительным циклом продаж.
#
# [2123] Оригинал:  С него всё начинается.
#     Референс: Все начинается с него.
#     Модель:    От него все начинается.
#
# [2124] Оригинал:  Всего обработано 38 работ по различным предметам 21 участников Турнира.
#     Референс: Всего 21 участник турнира обработал 38 работ на различные темы.
#     Модель:    В общей сложности 38 работ по различным дисциплинам были обработаны 21 участником турнира.
#
# [2125] Оригинал:  Он также намекнул на новую категорию продукции для Apple, хотя и мы слышали слухи раньше.
#     Референс: Он намекнул и на новую для Apple категорию продукции, хотя слухи об этом ходили и раньше.
#     Модель:    Он также намекнул о новой категории продуктов для Apple, хотя слухи об этом уже ходили.
#
# [2126] Оригинал:  Доверяете ли вы антикризисной идеологии властей?
#     Референс: Верите ли вы в антикризисную идеологию властей?
#     Модель:    Вы верите в антикризис-идеологию властей?
#
# [2127] Оригинал:  Участники (члены) общественной организации не отвечают по обязательствам организации, в которой участвуют в качестве членов, а организация не отвечает по обязательствам своих членов.
#     Референс: Члены общественного объединения не несут ответственности за обязательства организации, членом которой они являются, и организация не несет ответственности за обязательства своих членов.
#     Модель:    Участники (члены) общества не несут ответственности за обязательства организации, членом которой они являются, и Общество не несет ответственности за обязательства своих членов.
#
# [2128] Оригинал:  Нет, только не начинай опять.
#     Референс: Нет, просто не начинайте снова.
#     Модель:    Нет, начинать снова - только не надо.
#
# [2129] Оригинал:  Спасибо вам большое!"
#     Референс: Большое вам спасибо! "
#     Модель:    Большое вам спасибо! "
#
# [2130] Оригинал:  Как начать программировать для мобилного телефона.
#     Референс: Как начать программирование для мобильного телефона.
#     Модель:    Как начинать программирование для мобильных телефонов.
#
# [2131] Оригинал:  Дабы не навредить новой «мебели», в баре единовременно может находиться не более 45 человек.
#     Референс: Чтобы новая "мебель" не повредила, в одном баре может одновременно находиться не больше 45 человек.
#     Модель:    Для того чтобы новая мебель не повреждалась, в баре одновременно может находиться максимум 45 человек.
#
# [2132] Оригинал:  На первом этапе, который должен начаться в 2015 году, спутник Земли будут исследовать зонды "Луна‑Ресурс" и "Луна‑Глоб".
#     Референс: На первой фазе, которая начнется в 2015 г., зонды Luna Resource и Moon Globe займутся исследованием спутника Земли.
#     Модель:    На первой фазе, которая должна начнется с 2015 года, исследователями зондов Luna Resorce и Luna Globe будут исследоваться спутники Земли.
#
# [2133] Оригинал:  Стороны соглашения разрабатывают мероприятия по экономическому стимулированию работодателей и их объединений, активно участвующих в развитии социального партнерства, реализации мер по линиям приоритетных направлений.
#     Референс: Стороны соглашения вырабатывают меры по обеспечению экономических стимулов работодателям и их объединениям, активно вовлеченным в развитие социального партнерства и реализацию мероприятий по приоритетным направлениям.
#     Модель:    Стороны соглашения разрабатывают меры по стимулированию экономики, нацеленные на работодателей и объединения, активно участвующие в развитии социального партнёрства и реализовывающие мероприятия по приоритетным областям.
#
# [2134] Оригинал:  Ее выбросили на улицу около 2 дней назад, она очень запугана и нуждается в ласке и заботе!
#     Референс: Она была выкинута на улицу примерно 2 дня назад, ей очень страшно и она нуждается в заботе и внимании!
#     Модель:    Она была выброшена на улицу примерно 2 дня тому назад, страшно и ей нужна забота и покой!
#
# [2135] Оригинал:  Что мы знаем о Египте?
#     Референс: Что нам известно о Египте?
#     Модель:    Что нам известно об Египте?
#
# [2136] Оригинал:  Каждый раз не знаю, что отвечать.
#     Референс: Каждый раз я не знаю что ответить.
#     Модель:    Я каждый раз не знаю что сказать.
#
# [2137] Оригинал:  Время в пути до острова составит около 3,5 часов.
#     Референс: Продолжительность поездки на остров составит примерно 3,5 часа.
#     Модель:    На остров ехать будет около 3,5 часов.
#
# [2138] Оригинал:  С каждым годом мы только подтверждаем правильность нашей стратегии роста.
#     Референс: Каждый год мы подтверждаем только правильность своей стратегии роста.
#     Модель:    Каждый год подтверждаем правильность своей стратегии роста.
#
# [2139] Оригинал:  Я всё, всегда прощала и прощаю…
#     Референс: Я всегда все прощал и прощал...
#     Модель:    Я всегда прощаю и прощаю все...
#
# [2140] Оригинал:  Вместо привычной схемы «эконом-бизнес-первый» работает принцип «эконом-комфорт-бизнес».
#     Референс: Вместо обычной схемы "экономика - бизнес - прежде всего" действует принцип "экономика - комфорт - бизнес".
#     Модель:    Вместо традиционной схемы "экономичное предприятие - в первую очередь" действует принцип "экономичный комфорт - бизнес".
#
# [2141] Оригинал:  В этом году в программе впервые отдельная сессия посвящена автоматизации функции комплаенса.
#     Референс: В нынешнем году впервые в программе отдельной сессии посвящена автоматизация комплаенс-функций.
#     Модель:    Началась отдельная сессия в программе этого года, посвященная автоматизации функции соответствия требованиям.
#
# [2142] Оригинал:  И здесь есть два фактора: естественный отбор и фенотип.
#     Референс: Здесь два фактора - естественный отбор и фенотипность.
#     Модель:    И есть два фактора: естественный отбор и фенотип.
#
# [2143] Оригинал:  Все в норме, просто печень очень сильно забита, и только во время второй и последующих чисток "посыпятся" камни.
#     Референс: Все нормально, только печень сильно закупорена, и лишь во время второго и последующего очищения камни будут "посыпаться".
